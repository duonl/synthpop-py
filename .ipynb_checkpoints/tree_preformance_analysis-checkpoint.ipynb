# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import excel data
frames = []
for i in range(16):
    df_sheet = pd.read_excel(f"problematicData/diag_data{i}.xlsx")
    frames.append(df_sheet)

df = pd.concat(frames)
df
# Out:
#      Unnamed: 0  seed     col  n_nodes  n_nodes_used  is_regressor  \
# 0             0     0       0        1             1         False
# 1             1     0       1       23            23          True
# 2             2     0       2       27            27         False
# 3             3     0       3       29            29          True
# 4             4     0       4       31            31         False
# ..          ...   ...     ...      ...           ...           ...
# 96           96    15      96       31            20         False
# 97           97    15      97       19            19          True
# 98           98    15      98       29            16         False
# 99           99    15      99       31            31          True
# 100         100    15  target       25            25          True
#
#      unused_nodes  percentage
# 0               0    0.000000
# 1               0    0.000000
# 2               0    0.000000
# 3               0    0.000000
# 4               0    0.000000
# ..            ...         ...
# 96             11   35.483871
# 97              0    0.000000
# 98             13   44.827586
# 99              0    0.000000
# 100             0    0.000000
#
# [1616 rows x 8 columns]

# %%
fig, ax = plt.subplots()
plt.title= "total regressors and classifiers in the dataset"
n_reg = df["is_regressor"].sum()
n_clf = df.shape[0] -n_reg
sizes = [n_reg,n_clf]
labels = "total regressors","total classifiers"
ax.pie(sizes,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x18e6e486850>,
#   <matplotlib.patches.Wedge at 0x18e6e487d90>],
#  [Text(-0.01710713123828362, 1.0998669674377881, 'total regressors'),
#   Text(0.017107096277351748, -1.0998669679815636, 'total classifiers')])
# Error in callback <function _draw_all_if_interactive at 0x0000018E5EC839C0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\pyplot.py:278, in _draw_all_if_interactive()
#     276 def _draw_all_if_interactive() -> None:
#     277     if matplotlib.is_interactive():
# --> 278         draw_all()
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\figure.py:3264, in Figure.draw(self, renderer)
#    3261             # ValueError can occur when resizing a window.
#    3263     self.patch.draw(renderer)
# -> 3264     mimage._draw_list_compositing_images(
#    3265         renderer, self, artists, self.suppressComposite)
#    3267     renderer.close_group('figure')
#    3268 finally:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\axes\_base.py:3190, in _AxesBase.draw(self, renderer)
#    3187     for spine in self.spines.values():
#    3188         artists.remove(spine)
# -> 3190 self._update_title_position(renderer)
#    3192 if not self.axison:
#    3193     for _axis in self._axis_map.values():
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\axes\_base.py:3101, in _AxesBase._update_title_position(self, renderer)
#    3097     return
#    3099 titles = (self.title, self._left_title, self._right_title)
# -> 3101 if not any(title.get_text() for title in titles):
#    3102     # If the titles are all empty, there is no need to update their positions.
#    3103     return
#    3105 # Need to check all our twins too, aligned axes, and all the children
#    3106 # as well.
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\axes\_base.py:3101, in <genexpr>(.0)
#    3097     return
#    3099 titles = (self.title, self._left_title, self._right_title)
# -> 3101 if not any(title.get_text() for title in titles):
#    3102     # If the titles are all empty, there is no need to update their positions.
#    3103     return
#    3105 # Need to check all our twins too, aligned axes, and all the children
#    3106 # as well.
#
# AttributeError: 'str' object has no attribute 'get_text'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\backend_bases.py:2157, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2154     # we do this instead of `self.figure.draw_without_rendering`
#    2155     # so that we can inject the orientation
#    2156     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2157         self.figure.draw(renderer)
#    2158 if bbox_inches:
#    2159     if bbox_inches == "tight":
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\figure.py:3264, in Figure.draw(self, renderer)
#    3261             # ValueError can occur when resizing a window.
#    3263     self.patch.draw(renderer)
# -> 3264     mimage._draw_list_compositing_images(
#    3265         renderer, self, artists, self.suppressComposite)
#    3267     renderer.close_group('figure')
#    3268 finally:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\axes\_base.py:3190, in _AxesBase.draw(self, renderer)
#    3187     for spine in self.spines.values():
#    3188         artists.remove(spine)
# -> 3190 self._update_title_position(renderer)
#    3192 if not self.axison:
#    3193     for _axis in self._axis_map.values():
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\axes\_base.py:3101, in _AxesBase._update_title_position(self, renderer)
#    3097     return
#    3099 titles = (self.title, self._left_title, self._right_title)
# -> 3101 if not any(title.get_text() for title in titles):
#    3102     # If the titles are all empty, there is no need to update their positions.
#    3103     return
#    3105 # Need to check all our twins too, aligned axes, and all the children
#    3106 # as well.
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\synthpop-py-O9_SKGOk-py3.13\Lib\site-packages\matplotlib\axes\_base.py:3101, in <genexpr>(.0)
#    3097     return
#    3099 titles = (self.title, self._left_title, self._right_title)
# -> 3101 if not any(title.get_text() for title in titles):
#    3102     # If the titles are all empty, there is no need to update their positions.
#    3103     return
#    3105 # Need to check all our twins too, aligned axes, and all the children
#    3106 # as well.
#
# AttributeError: 'str' object has no attribute 'get_text'

# %%
m_clf = df["is_regressor"]==False
m_reg = df["is_regressor"]==True
m_no_target = df["col"] != "target"
m_has_difference = df["unused_nodes"] != 0

# %%
fig, ax = plt.subplots()
n_reg = df[m_has_difference]["is_regressor"].sum()
n_clf = df[m_has_difference].shape[0] -n_reg
sizes = [n_reg,n_clf]
labels = "total regressors","total classifiers"
ax.pie(sizes,labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x18e6e67cb90>,
#   <matplotlib.patches.Wedge at 0x18e6e67cf50>],
#  [Text(1.0996230573985013, 0.028794645987968895, 'total regressors'),
#   Text(-1.0996230523603687, -0.02879483838582812, 'total classifiers')],
#  [Text(0.599794394944637, 0.015706170538892124, '0.8%'),
#   Text(-0.5997943921965647, -0.01570627548317897, '99.2%')])

# %%
df["has_difference"] = m_has_difference
df[["is_regressor","has_difference"]].value_counts(normalize=True)
# Out:
# is_regressor  has_difference
# True          False             0.503094
# False         False             0.274134
#               True              0.220916
# True          True              0.001856
# Name: proportion, dtype: float64

# %%
df[m_clf][["is_regressor","has_difference"]].value_counts(normalize=True)
# Out:
# is_regressor  has_difference
# False         False             0.55375
#               True              0.44625
# Name: proportion, dtype: float64

# %%
df[m_reg][["is_regressor","has_difference"]].value_counts(normalize=False)
# Out:
# is_regressor  has_difference
# True          False             813
#               True                3
# Name: count, dtype: int64

# %%
df[m_reg][["is_regressor","has_difference"]].value_counts(normalize=True)*100
# Out:
# is_regressor  has_difference
# True          False             99.632353
#               True               0.367647
# Name: proportion, dtype: float64

# %%
sns.scatterplot(data=df[m_no_target],x="col",y="unused_nodes",hue="is_regressor")
# Out:
# <Axes: xlabel='col', ylabel='unused_nodes'>
